# %%
import numpy as np 
import pandas as pd 
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\91829\Downloads\covid_toy.csv")
print(data.head(),
data.describe(),
data.info())
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(data.drop(columns=['has_covid']),data['has_covid'],test_size=0.2,random_state=42)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        100 non-null    int64
#  1   gender     100 non-null    str
#  2   fever      90 non-null     float64
#  3   cough      100 non-null    str
#  4   city       100 non-null    str
#  5   has_covid  100 non-null    str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 4.8 KB
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# ...

# %%
data.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
from sklearn.compose import ColumnTransformer
traonsformer = ColumnTransformer(transformers=[('tnf1', SimpleImputer(),['fever']),
                                            ('tnf2',OrdinalEncoder(categories=[['Mild', 'Strong']]),['cough']),
                                            ('tnf3',OneHotEncoder(drop='first'),['gender','city'])]
                                 ,remainder='passthrough')

# %%
traonsformer.fit_transform(x_train)
# Out:
# array([[101.,   0.,   0.,   0.,   0.,   1.,  81.],
#        [100.,   0.,   0.,   0.,   1.,   0.,   5.],
#        [100.,   0.,   0.,   0.,   1.,   0.,  19.],
#        [100.,   0.,   1.,   1.,   0.,   0.,  27.],
#        [103.,   0.,   0.,   1.,   0.,   0.,  73.],
#        [103.,   1.,   1.,   0.,   1.,   0.,  70.],
#        [102.,   0.,   0.,   1.,   0.,   0.,  49.],
#        [101.,   1.,   0.,   0.,   1.,   0.,  51.],
#        [101.,   0.,   0.,   1.,   0.,   0.,  64.],
#        [101.,   0.,   0.,   0.,   1.,   0.,  83.],
#        [ 98.,   0.,   0.,   0.,   0.,   1.,  65.],
#        [104.,   0.,   0.,   0.,   0.,   0.,  18.],
#        [103.,   0.,   0.,   0.,   0.,   0.,  16.],
#        [104.,   0.,   1.,   0.,   1.,   0.,  16.],
#        [100.,   0.,   1.,   0.,   1.,   0.,  27.],
#        [101.,   0.,   0.,   0.,   0.,   0.,  84.],
#        [104.,   0.,   1.,   0.,   1.,   0.,  51.],
#        [102.,   0.,   0.,   0.,   0.,   0.,  69.],
# ...
